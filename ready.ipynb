# %% [markdown]
# # List of items in df
# Cabbage(Local)<br>
# Bamboo Shoot<br>
# Pumpkin<br>
# Carrot(Local)<br>
# Coriander Green<br>
# Raddish White(Local)<br>
# Spinach Leaf<br>
# Lime<br>
# Brd Leaf Mustard<br>
# Chilli Green<br>
# Cauli Local<br>
# Mushroom(Kanya)<br>
# Chilli Dry<br>
# Capsicum<br>
# Tamarind<br>
# Bottle Gourd<br>
# Tomato Small(Local)<br>
# Garlic Dry Chinese<br>
# Potato Red<br>
# Brinjal Long<br>
# Ginger<br>
# Onion Green<br>
# French Bean(Local)<br>
# Banana<br>
# Onion Dry (Indian)

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
clean_filled = pd.read_csv(r"C:\Users\adith\Documents\bmsce\2nd year\4th sem\Python\PROJECT\final_df", index_col=0)

# %%
def graph(item, item2, w = 10, h = 6):
    values = clean_filled.loc[item]
    values2 = clean_filled.loc[item2]
    plt.figure(figsize=(w, h))
    plt.plot(values)
    # plt.plot(values2)
    
    plt.xlabel('Days (not shown)')
    plt.ylabel('Value')
    plt.title(f'Values for {item} vs {item2} over all days')
    
    plt.show()

# %%
graph('Cabbage(Local)','Chilli Green',15)

# %%
import numpy as np
import pandas as pd
import matplotlib
print(np.__version__)
print(pd.__version__)
print(matplotlib.__version__)
# Out:
# 1.23.0
# 1.4.3
# 3.5.2

# %%
list_of_prices = clean_filled.loc['Cabbage(Local)']
print(list_of_prices)
